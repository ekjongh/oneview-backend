# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

SQLALCHEMY_DATABASE_URL = "oracle+cx_oracle://nwai:nwai123@10.203.13.202:8316/?service_name=xe&encoding=UTF-8&nencoding=UTF-8"

engine = create_engine(
    SQLALCHEMY_DATABASE_URL,
)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
db = SessionLocal()

# %%
# %%time
query = """
select base_date, area_jo_nm,  coalesce(round((sum(nvl(g5_total_data_qnt + sru_total_data_qnt, 0)) / (sum(nvl(total_data_qnt, 0)) + 1e-6)) * 100, 4), 0.0000) AS g5_off_ratio
from DASHBOARD_5G_OFF
group by base_date, area_jo_nm

"""
result = db.execute(query)
# print("TYPE: ", type(result))
# Out:
# CPU times: user 15.8 ms, sys: 4.52 ms, total: 20.3 ms
# Wall time: 374 ms

# %%
result.all()
# Out:
# [('20220501', '구로1조', Decimal('67.4236')),
#  ('20220505', '구로2조', Decimal('64.3376')),
#  ('20220505', '구로5조', Decimal('66.0387')),
#  ('20220506', '구로5조', Decimal('67.2649')),
#  ('20220506', '전남3조', Decimal('57.6219')),
#  ('20220507', '구로3조', Decimal('64.9967')),
#  ('20220511', '구로1조', Decimal('65.7596')),
#  ('20220509', '전남3조', Decimal('54.9223')),
#  ('20220510', '구로1조', Decimal('68.7464')),
#  ('20220510', '구로4조', Decimal('67.6481')),
#  ('20220514', '구로4조', Decimal('65.1529')),
#  ('20220514', '전남2조', Decimal('50.6938')),
#  ('20220515', '전남3조', Decimal('52.4844')),
#  ('20220519', '전남2조', Decimal('53.2172')),
#  ('20220517', '구로3조', Decimal('66.4814')),
#  ('20220517', '구로5조', Decimal('64.3835')),
#  ('20220517', '전남2조', Decimal('52.3837')),
#  ('20220518', '전남3조', Decimal('55.2844')),
#  ('20220524', '구로3조', Decimal('67.2227')),
#  ('20220524', '전남4조', Decimal('47.1709')),
#  ('20220523', '전남2조', Decimal('52.1367')),
#  ('20220528', '구로2조', Decimal('65.9087')),
#  ('20220526', '전남1조', Decimal('53.7597')),
#  ('20220530', '구로4조', Decimal('66.8257')),
#  ('20220530', '전남4조', Decimal('48.2184')),
#  ('20220531', '구로2조', Decimal('66.4053')),
#  ('20220508', '전남3조', Decimal('52.5904')),
#  ('20220502', '구로5조', Decimal('67.5981')),
#  ('20220502', '전남4조', Decimal('47.4775')),
#  ('20220505', '구로3조', Decimal('67.532')),
#  ('20220508', '구로1조', Decimal('66.5438')),
#  ('20220507', '구로5조', Decimal('64.1349')),
#  ('20220503', '전남1조', Decimal('54.1654')),
#  ('20220513', '전남1조', Decimal('53.4264')),
#  ('20220515', '전남1조', Decimal('51.9203')),
#  ('20220512', '전남4조', Decimal('46.5194')),
#  ('20220520', '구로3조', Decimal('66.7874')),
#  ('20220522', '전남3조', Decimal('53.3367')),
#  ('20220520', '전남1조', Decimal('54.7462')),
#  ('20220527', '구로3조', Decimal('67.9241')),
#  ('20220527', '전남1조', Decimal('54.9473')),
#  ('20220527', '전남3조', Decimal('55.2426')),
#  ('20220529', '전남4조', Decimal('47.5486')),
#  ('20220529', '구로1조', Decimal('66.9675')),
#  ('20220510', '전남4조', Decimal('48.0498')),
#  ('20220511', '전남4조', Decimal('46.1293')),
#  ('20220503', '구로2조', Decimal('65.1442')),
#  ('20220504', '구로5조', Decimal('67.6932')),
#  ('20220504', '전남1조', Decimal('54.7929')),
#  ('20220505', '구로1조', Decimal('66.095')),
#  ('20220511', '구로3조', Decimal('66.2475')),
#  ('20220511', '전남3조', Decimal('54.5508')),
#  ('20220513', '구로2조', Decimal('63.7735')),
#  ('20220513', '전남4조', Decimal('46.4531')),
#  ('20220518', '구로4조', Decimal('65.3912')),
#  ('20220521', '구로2조', Decimal('65.8368')),
#  ('20220527', '구로2조', Decimal('66.4171')),
#  ('20220526', '구로1조', Decimal('66.0518')),
#  ('20220529', '구로3조', Decimal('66.4601')),
#  ('20220530', '전남2조', Decimal('52.8168')),
#  ('20220531', '구로4조', Decimal('66.7125')),
#  ('20220501', '전남4조', Decimal('45.803')),
#  ('20220501', '전남2조', Decimal('51.0052')),
#  ('20220502', '구로1조', Decimal('67.5721')),
#  ('20220502', '구로4조', Decimal('67.4939')),
#  ('20220502', '구로3조', Decimal('67.5878')),
#  ('20220510', '구로2조', Decimal('67.8814')),
#  ('20220510', '구로3조', Decimal('68.576')),
#  ('20220510', '전남2조', Decimal('53.1517')),
#  ('20220516', '구로3조', Decimal('67.4591')),
#  ('20220514', '전남3조', Decimal('53.7969')),
#  ('20220514', '전남4조', Decimal('46.6683')),
#  ('20220512', '전남2조', Decimal('52.3769')),
#  ('20220519', '구로4조', Decimal('67.0594')),
#  ('20220521', '전남3조', Decimal('53.7915')),
#  ('20220525', '구로4조', Decimal('65.2535')),
#  ('20220525', '전남2조', Decimal('51.274')),
#  ('20220526', '전남4조', Decimal('47.034')),
#  ('20220530', '구로3조', Decimal('67.6792')),
#  ('20220528', '전남2조', Decimal('51.9072')),
#  ('20220501', '전남1조', Decimal('52.9325')),
#  ('20220503', '구로3조', Decimal('67.108')),
#  ('20220502', '구로2조', Decimal('65.9684')),
#  ('20220504', '구로1조', Decimal('67.2822')),
#  ('20220507', '전남1조', Decimal('50.6212')),
#  ('20220505', '전남4조', Decimal('45.8677')),
#  ('20220503', '전남4조', Decimal('46.9426')),
#  ('20220512', '구로2조', Decimal('66.3811')),
#  ('20220508', '전남4조', Decimal('45.5452')),
#  ('20220509', '전남4조', Decimal('46.3327')),
#  ('20220513', '구로1조', Decimal('64.5775')),
#  ('20220512', '전남3조', Decimal('54.3372')),
#  ('20220517', '구로1조', Decimal('65.1555')),
#  ('20220522', '구로4조', Decimal('65.6267')),
#  ('20220522', '구로2조', Decimal('65.2321')),
#  ('20220522', '구로5조', Decimal('66.3233')),
#  ('20220523', '전남1조', Decimal('54.2935')),
#  ('20220520', '전남4조', Decimal('46.0242')),
#  ('20220525', '구로5조', Decimal('64.8487')),
#  ('20220522', '구로1조', Decimal('66.4296')),
#  ('20220501', '구로2조', Decimal('66.6472')),
#  ('20220511', '전남2조', Decimal('51.264')),
#  ('20220508', '전남1조', Decimal('52.0668')),
#  ('20220509', '구로4조', Decimal('67.1919')),
#  ('20220509', '전남1조', Decimal('54.0498')),
#  ('20220520', '구로4조', Decimal('66.8308')),
#  ('20220520', '구로1조', Decimal('67.2403')),
#  ('20220527', '전남2조', Decimal('52.66')),
#  ('20220526', '구로3조', Decimal('66.0502')),
#  ('20220530', '구로2조', Decimal('66.8878')),
#  ('20220531', '전남3조', Decimal('54.3761')),
#  ('20220530', '전남3조', Decimal('55.6219')),
#  ('20220502', '전남2조', Decimal('52.7233')),
#  ('20220507', '전남4조', Decimal('44.3393')),
#  ('20220507', '전남3조', Decimal('51.1215')),
#  ('20220505', '전남2조', Decimal('50.4564')),
#  ('20220506', '전남1조', Decimal('56.055')),
#  ('20220509', '구로5조', Decimal('66.9453')),
#  ('20220513', '구로4조', Decimal('65.1588')),
#  ('20220514', '전남1조', Decimal('52.9808')),
#  ('20220515', '전남4조', Decimal('45.1008')),
#  ('20220520', '구로2조', Decimal('66.0245')),
#  ('20220518', '구로1조', Decimal('65.852')),
#  ('20220518', '전남4조', Decimal('46.6463')),
#  ('20220524', '구로2조', Decimal('65.9332')),
#  ('20220527', '구로5조', Decimal('66.8175')),
#  ('20220525', '전남3조', Decimal('54.8179')),
#  ('20220526', '구로4조', Decimal('65.5578')),
#  ('20220503', '구로4조', Decimal('66.6973')),
#  ('20220504', '전남4조', Decimal('47.8153')),
#  ('20220507', '구로1조', Decimal('64.7522')),
#  ('20220506', '구로3조', Decimal('68.2234')),
#  ('20220512', '구로3조', Decimal('67.3327')),
#  ('20220513', '전남3조', Decimal('53.1416')),
#  ('20220519', '전남3조', Decimal('56.2863')),
#  ('20220516', '전남3조', Decimal('54.8559')),
#  ('20220517', '구로4조', Decimal('64.8242')),
#  ('20220518', '구로3조', Decimal('65.0789')),
#  ('20220522', '전남1조', Decimal('52.5766')),
#  ('20220523', '구로4조', Decimal('67.2925')),
#  ('20220524', '구로5조', Decimal('65.9971')),
#  ('20220523', '전남3조', Decimal('55.7836')),
#  ('20220520', '전남2조', Decimal('53.0698')),
#  ('20220531', '전남1조', Decimal('54.5611')),
#  ('20220531', '구로1조', Decimal('67.3909')),
#  ('20220528', '전남3조', Decimal('54.9138')),
#  ('20220508', '구로3조', Decimal('66.9097')),
#  ('20220515', '구로1조', Decimal('66.1586')),
#  ('20220515', '전남2조', Decimal('50.5227')),
#  ('20220520', '구로5조', Decimal('65.9752')),
#  ('20220519', '구로1조', Decimal('67.3837')),
#  ('20220521', '전남1조', Decimal('53.141')),
#  ('20220524', '구로4조', Decimal('66.8741')),
#  ('20220521', '구로3조', Decimal('66.0901')),
#  ('20220526', '구로5조', Decimal('65.707')),
#  ('20220526', '구로2조', Decimal('65.3369')),
#  ('20220530', '전남1조', Decimal('54.8218')),
#  ('20220501', '구로4조', Decimal('66.268')),
#  ('20220503', '구로5조', Decimal('67.0597')),
#  ('20220507', '구로4조', Decimal('63.5675')),
#  ('20220507', '구로2조', Decimal('63.7637')),
#  ('20220506', '구로1조', Decimal('67.7069')),
#  ('20220508', '전남2조', Decimal('50.3974')),
#  ('20220513', '구로3조', Decimal('64.5596')),
#  ('20220513', '전남2조', Decimal('52.535')),
#  ('20220514', '구로1조', Decimal('66.0897')),
#  ('20220516', '구로5조', Decimal('67.2624')),
#  ('20220516', '구로1조', Decimal('67.7535')),
#  ('20220514', '구로2조', Decimal('65.6962')),
#  ('20220519', '구로2조', Decimal('66.1814')),
#  ('20220519', '구로3조', Decimal('67.3271')),
#  ('20220520', '전남3조', Decimal('54.9894')),
#  ('20220528', '구로4조', Decimal('65.7188')),
#  ('20220525', '구로3조', Decimal('65.5284')),
#  ('20220526', '전남3조', Decimal('54.5146')),
#  ('20220502', '전남1조', Decimal('54.7522')),
#  ('20220504', '전남3조', Decimal('55.9519')),
#  ('20220505', '구로4조', Decimal('65.7716')),
#  ('20220505', '전남3조', Decimal('53.2202')),
#  ('20220506', '구로2조', Decimal('66.08')),
#  ('20220503', '전남3조', Decimal('55.5178')),
#  ('20220511', '구로5조', Decimal('65.56')),
#  ('20220512', '구로5조', Decimal('66.5675')),
#  ('20220510', '전남1조', Decimal('55.3149')),
#  ('20220516', '구로2조', Decimal('67.1014')),
#  ('20220515', '구로3조', Decimal('66.265')),
#  ('20220512', '구로4조', Decimal('67.0455')),
#  ('20220517', '구로2조', Decimal('63.4428')),
#  ('20220523', '구로2조', Decimal('65.6486')),
#  ('20220524', '구로1조', Decimal('67.614')),
#  ('20220531', '전남2조', Decimal('52.473')),
#  ('20220528', '구로1조', Decimal('67.2015')),
#  ('20220528', '전남1조', Decimal('54.5847')),
#  ('20220501', '전남3조', Decimal('51.9375')),
#  ('20220508', '구로5조', Decimal('65.8652')),
#  ('20220511', '전남1조', Decimal('53.4523')),
#  ('20220509', '구로2조', Decimal('66.7883')),
#  ('20220514', '구로5조', Decimal('66.0323')),
#  ('20220515', '구로2조', Decimal('65.6018')),
#  ('20220521', '구로1조', Decimal('66.5259')),
#  ('20220529', '구로4조', Decimal('65.3033')),
#  ('20220529', '전남1조', Decimal('51.8572')),
#  ('20220529', '전남3조', Decimal('53.7057')),
#  ('20220531', '전남4조', Decimal('47.4182')),
#  ('20220531', '구로5조', Decimal('66.6884')),
#  ('20220501', '구로3조', Decimal('67.6606')),
#  ('20220501', '구로5조', Decimal('67.7608')),
#  ('20220505', '전남1조', Decimal('51.6346')),
#  ('20220503', '전남2조', Decimal('52.6923')),
#  ('20220511', '구로4조', Decimal('65.744')),
#  ('20220516', '전남1조', Decimal('53.9791')),
#  ('20220518', '전남1조', Decimal('53.7302')),
#  ('20220519', '구로5조', Decimal('67.0642')),
#  ('20220522', '전남4조', Decimal('45.6564')),
#  ('20220523', '구로3조', Decimal('67.1338')),
#  ('20220524', '전남2조', Decimal('52.2266')),
#  ('20220524', '전남3조', Decimal('54.9096')),
#  ('20220527', '구로4조', Decimal('67.2251')),
#  ('20220527', '구로1조', Decimal('67.6441')),
#  ('20220530', '구로5조', Decimal('66.9103')),
#  ('20220503', '구로1조', Decimal('67.0348')),
#  ('20220504', '전남2조', Decimal('52.4586')),
#  ('20220507', '전남2조', Decimal('49.6205')),
#  ('20220506', '구로4조', Decimal('66.6179')),
#  ('20220509', '구로3조', Decimal('67.7664')),
#  ('20220513', '구로5조', Decimal('64.6477')),
#  ('20220516', '구로4조', Decimal('67.7174')),
#  ('20220515', '구로5조', Decimal('65.3373')),
#  ('20220512', '전남1조', Decimal('53.6239')),
#  ('20220519', '전남4조', Decimal('45.8495')),
#  ('20220517', '전남1조', Decimal('54.3558')),
#  ('20220517', '전남4조', Decimal('46.3717')),
#  ('20220518', '구로2조', Decimal('65.1845')),
#  ('20220518', '구로5조', Decimal('65.0237')),
#  ('20220521', '전남2조', Decimal('51.8884')),
#  ('20220522', '구로3조', Decimal('66.2853')),
#  ('20220523', '구로1조', Decimal('67.5924')),
#  ('20220523', '전남4조', Decimal('47.053')),
#  ('20220521', '구로4조', Decimal('65.3713')),
#  ('20220527', '전남4조', Decimal('48.5311')),
#  ('20220528', '구로5조', Decimal('65.1966')),
#  ('20220525', '구로2조', Decimal('64.3815')),
#  ('20220525', '전남1조', Decimal('53.1109')),
#  ('20220526', '전남2조', Decimal('51.7743')),
#  ('20220529', '구로2조', Decimal('65.4199')),
#  ('20220529', '구로5조', Decimal('65.1219')),
#  ('20220530', '구로1조', Decimal('67.8286')),
#  ('20220531', '구로3조', Decimal('66.9265')),
#  ('20220504', '구로4조', Decimal('67.5111')),
#  ('20220504', '구로3조', Decimal('67.6431')),
#  ('20220504', '구로2조', Decimal('65.9708')),
#  ('20220508', '구로4조', Decimal('64.2998')),
#  ('20220508', '구로2조', Decimal('65.4884')),
#  ('20220506', '전남2조', Decimal('54.5779')),
#  ('20220506', '전남4조', Decimal('48.8031')),
#  ('20220510', '전남3조', Decimal('56.0629')),
#  ('20220511', '구로2조', Decimal('65.3359')),
#  ('20220510', '구로5조', Decimal('67.7415')),
#  ('20220515', '구로4조', Decimal('64.5447')),
#  ('20220519', '전남1조', Decimal('54.1031')),
#  ('20220516', '전남2조', Decimal('53.0411')),
#  ('20220518', '전남2조', Decimal('51.7525')),
#  ('20220522', '전남2조', Decimal('50.0001')),
#  ('20220524', '전남1조', Decimal('54.7751')),
#  ('20220523', '구로5조', Decimal('66.9346')),
#  ('20220521', '구로5조', Decimal('65.4344')),
#  ('20220528', '구로3조', Decimal('67.0949')),
#  ('20220525', '전남4조', Decimal('46.1522')),
#  ('20220528', '전남4조', Decimal('48.5565')),
#  ('20220502', '전남3조', Decimal('55.2976')),
#  ('20220512', '구로1조', Decimal('67.0304')),
#  ('20220509', '구로1조', Decimal('68.0604')),
#  ('20220509', '전남2조', Decimal('52.0634')),
#  ('20220514', '구로3조', Decimal('66.7154')),
#  ('20220516', '전남4조', Decimal('46.2913')),
#  ('20220517', '전남3조', Decimal('54.8283')),
#  ('20220521', '전남4조', Decimal('46.8337')),
#  ('20220525', '구로1조', Decimal('65.7226')),
#  ('20220529', '전남2조', Decimal('50.8121'))]

# %%
from sqlalchemy.orm import Session
from app import schemas, models
from sqlalchemy import func, select, between, case
from datetime import datetime, timedelta

def get_offloading_compare_by_group_date(db: Session, group: str, date:str=None):
    sum_5g_data = func.sum(func.nvl(models.Offloading.g5_total_data_qnt, 0.0))
    sum_sru_data = func.sum(func.nvl(models.Offloading.sru_total_data_qnt, 0.0))
    sum_total_data = func.sum(func.nvl(models.Offloading.total_data_qnt, 0.0))
    g5_off_ratio = (sum_5g_data + sum_sru_data) / (sum_total_data + sum_sru_data + 1e-6) * 100
    g5_off_ratio = func.round(g5_off_ratio, 4)
    g5_off_ratio = func.coalesce(g5_off_ratio, 0.0).label("g5_off_ratio")

    entities = [
        models.Offloading.base_date,
        models.Offloading.area_jo_nm
    ]
    entities_groupby = [
        g5_off_ratio
    ]
    stmt = select(*entities, *entities_groupby)

    if not date:
        date = datetime.today().strftime("%Y%m%d")
        yesterday = (datetime.today() - timedelta(1)).strftime("%Y%m%d")
    
    stmt = stmt.where(between(models.Offloading.base_date, date, date))

    if group.endswith("팀") or group.endswith("부"):
        stmt = stmt.where(models.Offloading.bts_oper_team_nm == group)
        

    stmt = stmt.group_by(*entities).having(g5_off_ratio>0).order_by(g5_off_ratio.asc())
    query_result = db.execute(stmt).all()
    return query_result

# %%
date = "20220505"
yesterday = (datetime.strptime(date, "%Y%m%d") - timedelta(1)).strftime("%Y%m%d")

group = "구로엔지니어링부"

sum_5g_data = func.sum(func.nvl(models.Offloading.g5_total_data_qnt, 0.0))
sum_sru_data = func.sum(func.nvl(models.Offloading.sru_total_data_qnt, 0.0))
sum_total_data = func.sum(func.nvl(models.Offloading.total_data_qnt, 0.0))
g5_off_ratio = (sum_5g_data + sum_sru_data) / (sum_total_data + sum_sru_data + 1e-6) * 100
g5_off_ratio = func.round(g5_off_ratio, 4)
g5_off_ratio = func.coalesce(g5_off_ratio, 0.0).label("g5_off_ratio")
entities = [
    models.Offloading.base_date,
    models.Offloading.area_jo_nm
]
entities_groupby = [
    g5_off_ratio
]
stmt = select(*entities, *entities_groupby)
if not date:
    date = datetime.today().strftime("%Y%m%d")
    yesterday = (datetime.today() - timedelta(1)).strftime("%Y%m%d")

stmt = stmt.where(between(models.Offloading.base_date, yesterday, date))
if group.endswith("팀") or group.endswith("부"):
    stmt = stmt.where(models.Offloading.bts_oper_team_nm == group)
    
stmt = stmt.group_by(*entities).having(g5_off_ratio>0).order_by(g5_off_ratio.asc())
query_result = db.execute(stmt).all()

# %%
def split_past_current_values_day(x, date):
    yesterday = (datetime.strptime(date, "%Y%m%d") - timedelta(1)).strftime("%Y%m%d")
    past = list(filter(lambda x: x[0] == yesterday, x))
    current = list(filter(lambda x: x[0] == date, x))
    return (past, current)

# %%
results = []

for k in set(map(lambda x: x[1], query_result)):
    values = list(filter(lambda x: x[1] == k, query_result))
    past, current = split_past_current_values_day(values, date)
    tmp = {}
    tmp["group"] = k
    tmp["past_value"] = 
    tmp["current_value"] = 
    list.append(tmp)
# Out:
# 구로3조
# 구로4조
# 구로1조
# 구로2조
# 구로5조

# %%
list(filter(lambda x: x[0] == "20220505", query_result))
# Out:
# [('20220505', '구로2조', 41.9514),
#  ('20220505', '구로1조', 42.3753),
#  ('20220505', '구로4조', 42.5593),
#  ('20220505', '구로5조', 42.5731),
#  ('20220505', '구로3조', 43.0914)]
